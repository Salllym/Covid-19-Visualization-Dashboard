# %%
import pandas as pd

# %%
# Name of the CSV file
file = './Resources/uncleaned_covid_cases.csv'

# %%
df = pd.read_csv(file, encoding="UTF-8")

# %%
df.head()
# Out:
#   State/Territory  Total Cases  Confirmed Cases  Probable Cases  \
# 0         Alabama    1333137.0         957838.0        375299.0
# 1          Alaska     257263.0              0.0             0.0
# 2  American Samoa       6270.0              0.0             0.0
# 3         Arizona    2093680.0        1845454.0        248226.0
# 4        Arkansas     852229.0              0.0             0.0
#
#    Cases in Last 7 Days  Case Rate per 100000  Total Deaths  Confirmed Deaths  \
# 0                8836.0               27189.0       19696.0           15118.0
# 1                1838.0               35167.0        1252.0               NaN
# 2                  78.0               13230.0          31.0               NaN
# 3               16334.0               28764.0       30400.0           26426.0
# 4                4418.0               28240.0       11528.0               NaN
#
#    Probable Deaths  Deaths in Last 7 Days  ...  # Tests per 100K  \
# ...

# %%
#select columns
file_cases = df[["Total Cases", "Cases in Last 7 Days", "Case Rate per 100000", "Total Deaths", "Deaths in Last 7 Days", "Death Rate per 100000", "7-Day Cases Rate per 100000", "7-Day Death Rate per 100000", "New Cases", "New Deaths"]]

# %%
file_cases.head()
# Out:
#    Total Cases  Cases in Last 7 Days  Case Rate per 100000  Total Deaths  \
# 0    1333137.0                8836.0               27189.0       19696.0
# 1     257263.0                1838.0               35167.0        1252.0
# 2       6270.0                  78.0               13230.0          31.0
# 3    2093680.0               16334.0               28764.0       30400.0
# 4     852229.0                4418.0               28240.0       11528.0
#
#    Deaths in Last 7 Days  Death Rate per 100000  7-Day Cases Rate per 100000  \
# 0                    1.0                  401.0                        180.2
# 1                    0.0                  171.0                        251.2
# 2                    0.0                   65.0                        164.6
# 3                   28.0                  417.0                        224.4
# 4                   17.0                  382.0                        146.4
#
#    7-Day Death Rate per 100000  New Cases  New Deaths
# ...

# %%
file_cases.to_csv("./Resources/cleaned_covid_cases.csv", index=False)

# %%
file2 = "./Resources/uncleaned_covid_vaccine.csv"

# %%
df2 = pd.read_csv(file, encoding="UTF-8")

# %%
df.head()
# Out:
#   State/Territory  Total Cases  Confirmed Cases  Probable Cases  \
# 0         Alabama    1333137.0         957838.0        375299.0
# 1          Alaska     257263.0              0.0             0.0
# 2  American Samoa       6270.0              0.0             0.0
# 3         Arizona    2093680.0        1845454.0        248226.0
# 4        Arkansas     852229.0              0.0             0.0
#
#    Cases in Last 7 Days  Case Rate per 100000  Total Deaths  Confirmed Deaths  \
# 0                8836.0               27189.0       19696.0           15118.0
# 1                1838.0               35167.0        1252.0               NaN
# 2                  78.0               13230.0          31.0               NaN
# 3               16334.0               28764.0       30400.0           26426.0
# 4                4418.0               28240.0       11528.0               NaN
#
#    Probable Deaths  Deaths in Last 7 Days  ...  # Tests per 100K  \
# ...

# %%
df2.head()
# Out:
#   State/Territory  Total Cases  Confirmed Cases  Probable Cases  \
# 0         Alabama    1333137.0         957838.0        375299.0
# 1          Alaska     257263.0              0.0             0.0
# 2  American Samoa       6270.0              0.0             0.0
# 3         Arizona    2093680.0        1845454.0        248226.0
# 4        Arkansas     852229.0              0.0             0.0
#
#    Cases in Last 7 Days  Case Rate per 100000  Total Deaths  Confirmed Deaths  \
# 0                8836.0               27189.0       19696.0           15118.0
# 1                1838.0               35167.0        1252.0               NaN
# 2                  78.0               13230.0          31.0               NaN
# 3               16334.0               28764.0       30400.0           26426.0
# 4                4418.0               28240.0       11528.0               NaN
#
#    Probable Deaths  Deaths in Last 7 Days  ...  # Tests per 100K  \
# ...

# %%
#select columns
file_vaccine = df2[["State/Territory","Total Doses Distributed","Doses Distributed per 100K"]]
                    ##"Total Doses Administered by State where Administered","Doses Administered per 100k by State where Administered","People Fully Vaccinated by State of Residence"]]
                    #,"Percent of Total Pop Fully Vaccinated by State of Residence","People 18+ Fully Vaccinated by State of Residence","Percent of 18+ Pop Fully Vaccinated by State of Residence", "Percent of 18+ Pop Fully Vaccinated by State of Residence","People 12+ Fully Vaccinated by State of Residence","People 5+ Fully Vaccinated by State of Residence","Latitude","Longitude"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-d5ed0de73a35> in <module>
#       1 #select columns
# ----> 2 file_vaccine = df2[["State/Territory","Total Doses Distributed","Doses Distributed per 100K"]]
#       3                     ##"Total Doses Administered by State where Administered","Doses Administered per 100k by State where Administered","People Fully Vaccinated by State of Residence"]]
#       4                     #,"Percent of Total Pop Fully Vaccinated by State of Residence","People 18+ Fully Vaccinated by State of Residence","Percent of 18+ Pop Fully Vaccinated by State of Residence", "Percent of 18+ Pop Fully Vaccinated by State of Residence","People 12+ Fully Vaccinated by State of Residence","People 5+ Fully Vaccinated by State of Residence","Latitude","Longitude"]]
#
# ...
