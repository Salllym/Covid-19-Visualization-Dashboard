# %% [markdown]
# # Data CLeaning

# %%
import pandas as pd

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
# Name of CSV file
file = "../Resources/covid_cases.csv"

#Read CSV
case_df = pd.read_csv(file, encoding="UTF-8")
case_df.head()
# Out:
#   State/Territory  Total Cases  Confirmed Cases  Probable Cases  \
# 0         Alabama    1333137.0         957838.0        375299.0
# 1          Alaska     257263.0              0.0             0.0
# 2  American Samoa       6270.0              0.0             0.0
# 3         Arizona    2093680.0        1845454.0        248226.0
# 4        Arkansas     852229.0              0.0             0.0
#
#    Cases in Last 7 Days  Case Rate per 100000  Total Deaths  Confirmed Deaths  \
# 0                8836.0               27189.0       19696.0           15118.0
# 1                1838.0               35167.0        1252.0               NaN
# 2                  78.0               13230.0          31.0               NaN
# 3               16334.0               28764.0       30400.0           26426.0
# 4                4418.0               28240.0       11528.0               NaN
#
#    Probable Deaths  Deaths in Last 7 Days  ...  % Positive Last 30 Days  \
# ...

# %%
# Name of CSV file
file2 = "../Resources/covid_vaccine.csv"

#Read CSV
vaccine_df = pd.read_csv(file2, encoding="UTF-8")
vaccine_df.head()
# Out:
#   State/Territory  Total Doses Distributed  Doses Distributed per 100K  \
# 0   United States                758129055                    228346.0
# 1          Alaska                  1609665                    220036.0
# 2         Alabama                 10035640                    204676.0
# 3        Arkansas                  6461880                    214125.0
# 4  American Samoa                   121410                    256182.0
#
#    18+ Doses Distributed per 100K  \
# 0                        293553.0
# 1                        291838.0
# 2                        263066.0
# 3                        278812.0
# 4                        387458.0
#
#    Total Doses Administered by State where Administered  \
# 0                                          592269252
# 1                                            1171773
# 2                                            6402751
# 3                                            4333404
# 4                                             111347
# ...

# %%
# Name of CSV file
file3 = "../Resources/states_long_lat.csv"

#Read CSV
states_df = pd.read_csv(file3, encoding="UTF-8")
states_df.head()
# Out:
#   State/Territory   latitude   longitude
# 0          Alaska  63.588753 -154.493062
# 1         Alabama  32.318231  -86.902298
# 2        Arkansas  35.201050  -91.831833
# 3         Arizona  34.048928 -111.093731
# 4      California  36.778261 -119.417932

# %%
case_df = case_df.merge(states_df,on='State/Territory')
case_df
# Out:
# Empty DataFrame
# Columns: [Total Cases, Confirmed Cases, Probable Cases, Cases in Last 7 Days, Case Rate per 100000, Total Deaths, Confirmed Deaths, Probable Deaths, Deaths in Last 7 Days, Death Rate per 100000, 7-Day Cases Rate per 100000, 7-Day Death Rate per 100000, Total % Positive, % Positive Last 30 Days, % Positive Last 7 Days, # Tests per 100K, Total # Tests, # Tests per 100K Last 7 Days, Total # Tests Last 7 Days, # Tests per 100K Last 30 Days, Total # Tests Last 30 Days, New Cases, New Deaths, latitude_x, longitude_x, name_x, latitude_y, longitude_y, name_y, latitude_x, longitude_x, name_x, latitude_y, longitude_y, name_y, latitude_x, longitude_x, latitude_y, longitude_y, State/Territory, latitude, longitude]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# ### Create new dataframe with select columns

# %%
#select columns
file_cases = df1[["State/Territory", "Total Cases", "Cases in Last 7 Days", "Case Rate per 100000", "Total Deaths", "Deaths in Last 7 Days", "Death Rate per 100000", "7-Day Cases Rate per 100000", "7-Day Death Rate per 100000", "New Cases", "New Deaths", "Latitude", "Longitude"]]

# %%
file_cases.head()
# Out:
#   State/Territory  Total Cases  Cases in Last 7 Days  Case Rate per 100000  \
# 0         Alabama    1333137.0                8836.0               27189.0
# 1          Alaska     257263.0                1838.0               35167.0
# 2  American Samoa       6270.0                  78.0               13230.0
# 3         Arizona    2093680.0               16334.0               28764.0
# 4        Arkansas     852229.0                4418.0               28240.0
#
#    Total Deaths  Deaths in Last 7 Days  Death Rate per 100000  \
# 0       19696.0                    1.0                  401.0
# 1        1252.0                    0.0                  171.0
# 2          31.0                    0.0                   65.0
# 3       30400.0                   28.0                  417.0
# 4       11528.0                   17.0                  382.0
#
#    7-Day Cases Rate per 100000  7-Day Death Rate per 100000  New Cases  \
# ...

# %%
file_cases.to_csv("../Resources/cleaned_covid_cases.csv", index=False)

# %%
file2 = "../Resources/uncleaned_covid_vaccine.csv"

# %%
df2 = pd.read_csv(file2, encoding="UTF-8")

# %%
df2.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Distributed  \
# 0                  United States                758129055
# 1                         Alaska                  1609665
# 2                        Alabama                 10035640
# 3                       Arkansas                  6461880
# 4                 American Samoa                   121410
#
#    Doses Distributed per 100K  18+ Doses Distributed per 100K  \
# 0                    228346.0                        293553.0
# 1                    220036.0                        291838.0
# 2                    204676.0                        263066.0
# 3                    214125.0                        278812.0
# 4                    256182.0                        387458.0
#
#    Total Doses Administered by State where Administered  \
# 0                                          592269252
# 1                                            1171773
# 2                                            6402751
# ...

# %%
#select columns
file_vaccine = df2[["State/Territory/Federal Entity","Total Doses Distributed","Doses Distributed per 100K", 
                    "Total Doses Administered by State where Administered","Doses Administered per 100k by State where Administered","People Fully Vaccinated by State of Residence"
                    ,"Percent of Total Pop Fully Vaccinated by State of Residence","People 18+ Fully Vaccinated by State of Residence","Percent of 18+ Pop Fully Vaccinated by State of Residence", "Percent of 18+ Pop Fully Vaccinated by State of Residence","People 12+ Fully Vaccinated by State of Residence", "Percent of 12+ Pop Fully Vaccinated by State of Residence", "People 5+ Fully Vaccinated by State of Residence", "Percent of 5+ Pop Fully Vaccinated by State of Residence", "Latitude","Longitude"]]

# %%
file_vaccine.to_csv("../Resources/cleaned_covid_vaccine.csv", index=False)
